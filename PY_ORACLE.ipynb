# %%
import getpass
import oracledb

# %%
pw = getpass.getpass("Enter password: ")

# %%
connection = oracledb.connect(
    user="gisslive240620",
    password="log",
    dsn="172.16.0.135/orcl")
# Out:
# ---------------------------------------------------------------------------
# NotSupportedError                         Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 connection = oracledb.connect(
#       2     user="gisslive240620",
#       3     password="log",
#       4     dsn="172.16.0.135/orcl")
#
# File ~\anaconda3\lib\site-packages\oracledb\connection.py:1013, in _connection_factory.<locals>.connect(dsn, pool, conn_class, params, **kwargs)
#    1011 if not issubclass(conn_class, Connection):
#    1012     errors._raise_err(errors.ERR_INVALID_CONN_CLASS)
# -> 1013 return conn_class(dsn=dsn, pool=pool, params=params, **kwargs)
#
# File ~\anaconda3\lib\site-packages\oracledb\connection.py:135, in Connection.__init__(self, dsn, pool, params, **kwargs)
#     133     else:
#     134         impl = thin_impl.ThinConnImpl(dsn, params_impl)
# --> 135         impl.connect(params_impl)
#     136 else:
#     137     impl = thick_impl.ThickConnImpl(dsn, params_impl)
#
# File src\oracledb\impl/thin/connection.pyx:318, in oracledb.thin_impl.ThinConnImpl.connect()
#
# File src\oracledb\impl/thin/connection.pyx:206, in oracledb.thin_impl.ThinConnImpl._connect_with_params()
#
# File src\oracledb\impl/thin/connection.pyx:177, in oracledb.thin_impl.ThinConnImpl._connect_with_description()
#
# File src\oracledb\impl/thin/connection.pyx:118, in oracledb.thin_impl.ThinConnImpl._connect_with_address()
#
# File src\oracledb\impl/thin/protocol.pyx:211, in oracledb.thin_impl.Protocol._connect_phase_two()
#
# File ~\anaconda3\lib\site-packages\oracledb\errors.py:111, in _raise_err(error_num, context_error_message, cause, **args)
#     109     message = f"{message}\n{context_error_message}"
#     110 exc_type = ERR_EXCEPTION_TYPES[error_num // 1000]
# --> 111 raise exc_type(_Error(message)) from cause
#
# NotSupportedError: DPY-3010: connections to this database server version are not supported by python-oracledb in thin mode

# %%
cursor = connection.cursor()

# Create a table

cursor.execute("""
    begin
        execute immediate 'drop table todoitem';
        exception when others then if sqlcode <> -942 then raise; end if;
    end;""")

cursor.execute("""
    create table todoitem (
        id number generated always as identity,
        description varchar2(4000),
        creation_ts timestamp with time zone default current_timestamp,
        done number(1,0),
        primary key (id))""")

# Insert some data

rows = [ ("Task 1", 0 ),
         ("Task 2", 0 ),
         ("Task 3", 1 ),
         ("Task 4", 0 ),
         ("Task 5", 1 ) ]

cursor.executemany("insert into todoitem (description, done) values(:1, :2)", rows)
print(cursor.rowcount, "Rows Inserted")

connection.commit()

# Now query the rows back
for row in cursor.execute('select description, done from todoitem'):
    if (row[1]):
        print(row[0], "is done")
    else:
        print(row[0], "is NOT done")

# %%
import pandas as pd

# %%
w=pd.read_csv('D:\\documents\\empma data.csv', encoding='iso-8859-1')
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_12264\346122204.py:1: DtypeWarning: Columns (22,29,32,42,62,69,96,130,146,154,160,165,166,169,171,181,185,186,191,192,215,218,226,227,229,234,235,237) have mixed types. Specify dtype option on import or set low_memory=False.
#   w=pd.read_csv('D:\\documents\\empma data.csv', encoding='iso-8859-1')

# %%
w
# Out:
#              EMPMAID CANCEL  SOURCEID  MAPNAME USERNAME MODIFIEDON CREATEDBY  \
# 0      1431990002012      F         0      NaN    admin   09-01-20     admin
# 1      1431990002013      F         0      NaN    admin   09-01-20     admin
# 2      1425330000210      F         0      NaN   profit   08-01-20    profit
# 3      1429330002838      F         0      NaN    admin   09-01-20     admin
# 4      1429660002512      F         0      NaN    admin   09-01-20     admin
# ...              ...    ...       ...      ...      ...        ...       ...
# 28148  1736990000196      F         0      NaN   Harish   02-03-21    Harish
# 28149  1736990000198      F         0      NaN   Harish   02-03-21    Harish
# 28150  1667330000565      F         0      NaN   Harish   08-03-21    Harish
# 28151  1667330000567      F         0      NaN   Harish   08-03-21    Harish
# 28152  1667330000569      F         0      NaN   Harish   08-03-21    Harish
#
#       CREATEDON  WKID  APP_LEVEL  ...  DEATHCASE  DEATHDATE  DEATHREASON  \
# 0      09-01-20   NaN          1  ...          F        NaN          NaN
# 1      09-01-20   NaN          1  ...          F        NaN          NaN
# 2      08-01-20   NaN          1  ...          F        NaN          NaN
# 3      09-01-20   NaN          1  ...          F        NaN          NaN
# 4      09-01-20   NaN          1  ...          F        NaN          NaN
# ...         ...   ...        ...  ...        ...        ...          ...
# 28148  02-03-21   NaN          1  ...          F        NaN          NaN
# 28149  02-03-21   NaN          1  ...          F        NaN          NaN
# 28150  08-03-21   NaN          1  ...          F        NaN          NaN
# 28151  08-03-21   NaN          1  ...          F        NaN          NaN
# 28152  08-03-21   NaN          1  ...          F        NaN          NaN
#
#        FINYEAR  APPLTRNO USERTYPE  XMAPNAME  TEMPEMPID  REQUESTMAILID  \
# 0          NaN       NaN      NaN       NaN        NaN            NaN
# 1          NaN       NaN      NaN       NaN        NaN            NaN
# 2      2020-21       NaN      NaN       NaN        NaN            NaN
# 3          NaN       NaN      NaN       NaN        NaN            NaN
# 4          NaN       NaN      NaN       NaN        NaN            NaN
# ...        ...       ...      ...       ...        ...            ...
# 28148      NaN       NaN    ADMIN       NaN        NaN            NaN
# 28149      NaN       NaN    ADMIN       NaN        NaN            NaN
# 28150      NaN       NaN      COT       NaN        NaN            NaN
# 28151      NaN       NaN      COT       NaN        NaN            NaN
# 28152      NaN       NaN      COT       NaN        NaN            NaN
#
#       PENSIONWAGES
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ...            ...
# 28148          NaN
# 28149          NaN
# 28150          NaN
# 28151          NaN
# 28152          NaN
#
# [28153 rows x 241 columns]

# %%
w.isnull().sum()
# Out:
# EMPMAID              0
# CANCEL               0
# SOURCEID             0
# MAPNAME          28153
# USERNAME             0
#                  ...
# USERTYPE         26208
# XMAPNAME         28143
# TEMPEMPID        28153
# REQUESTMAILID    28153
# PENSIONWAGES     28153
# Length: 241, dtype: int64
